# %% [markdown]
# # MGA Analysis
#
# This notebook analyzes the solutions from Modeling-to-Generate-Alternatives in Temoa

# %%
from data_parser import get_output_files
from data_parser import make_emissions_plots, make_reactor_plots, make_capacity_plots, make_plots
from data_parser import get_scenario_name

# %%
output = get_output_files()
output
# Out:
# ['./data_files/cost_cost2050_model/cost2050_OutputLog.log',
#  './data_files/cost_cost2050_mga_0_model/cost2050_mga_0_OutputLog.log',
#  './data_files/cost_cost2050_mga_2_model/cost2050_mga_2_OutputLog.log',
#  './data_files/cost_cost2050_mga_1_model/cost2050_mga_1_OutputLog.log',
#  './data_files/cost_cost2050_mga_3_model/cost2050_mga_3_OutputLog.log']

# %%
make_plots(output, to_save=False)

# %%
make_reactor_plots(output, to_save=False)

# %%
make_plots(output, to_save=True)
